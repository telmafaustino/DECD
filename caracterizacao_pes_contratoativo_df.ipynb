# %% [markdown]
# <a href="https://colab.research.google.com/github/telmafaustino/DECD/blob/main/caracterizacao_pes_contratoativo_df.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd

import os

data_path = 'https://raw.githubusercontent.com/telmafaustino/DECD/main/'

caracterizacao_pes_contratoativo_df= pd.read_excel(data_path + 'caracterizacaopescontratoativo.xlsx', index_col=None)

# %%
caracterizacao_pes_contratoativo_df['Ano'].describe()
# Out:
# count    393706.000000
# mean       2022.719268
# std           0.664273
# min        2022.000000
# 25%        2022.000000
# 50%        2023.000000
# 75%        2023.000000
# max        2024.000000
# Name: Ano, dtype: float64

# %%
caracterizacao_pes_contratoativo_df
# Out:
#          Ano  Mês CodDistritoConcelhoFreguesia Distrito          Concelho  \
# 0       2023   12                       181811    Viseu       Sernancelhe
# 1       2023   12                       091109   Guarda           Sabugal
# 2       2024    3                       182323    Viseu             Viseu
# 3       2022    5                       180107    Viseu           Armamar
# 4       2022   11                       150411  Setúbal          Barreiro
# ...      ...  ...                          ...      ...               ...
# 393701  2022    9                       030906    Braga  Póvoa de Lanhoso
# 393702  2022    9                       150506  Setúbal          Grândola
# 393703  2023    3                       180326    Viseu      Castro daire
# 393704  2023    7                       011813   Aveiro             Vagos
# 393705  2023    7                       030104    Braga            Amares
#
#                                                 Freguesia  Tipo de Instalação  \
# ...
